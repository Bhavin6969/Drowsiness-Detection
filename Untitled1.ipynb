# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ...
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\Bhavin Joshi/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-6-25 Python-3.10.5 torch-2.0.1+cpu CPU
#
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 14.1M/14.1M [00:39<00:00, 376kB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img='C:/Users/Bhavin Joshi/Desktop/Prog/Python/Drowsiness/1.jpg'

# %%
results=model(img)
results.print()
# Out:
# image 1/1: 675x1200 1 person, 1 tie, 1 wine glass
# Speed: 353.8ms pre-process, 1568.1ms inference, 190.4ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    results=model(frame)
    cv2.imshow('YOLO',np.squeeze(results.render()))
    if cv2.waitKey(10) & 0xff==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Training the Model

# %%
import uuid #to import self images
import os    
import time #to give break between taking images

# %%
IMAGES_PATH=os.path.join('data','images')
labels=['awake','drowsy']
number_imgs=20

# %%
cap= cv2.VideoCapture(0)
for label in labels:
    print("Collecting images for {}".format(label))
    time.sleep(5)
    
    
    for img_num in range(number_imgs):
        print("Collecting images for {}, image number {}".format(label,img_num))
        ret,frame=cap.read()
        imgname=os.path.join(IMAGES_PATH,label+'.'+ str(uuid.uuid1())+'.jpg')
        cv2.imwrite(imgname,frame)
        cv2.imshow("Image Collection",frame)
        time.sleep(2)
    if cv2.waitKey(10) & 0xff==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH,labels[0]+ '.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.79ca7781-3150-11ee-a9f6-2c337afe2f50.jpg

# %%
for label in labels:
    print("Collecting images for {}".format(label))
    for img_num in range(number_imgs):
        print("Collecting images for {}, image number {}".format(label,img_num))
        imgname=os.path.join(IMAGES_PATH,label+'.'+ str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.2a52e040-3150-11ee-91b6-2c337afe2f50.jpg
# ...
# data\images\awake.2a52e041-3150-11ee-8141-2c337afe2f50.jpg
# ...
# data\images\awake.2a52e042-3150-11ee-807f-2c337afe2f50.jpg
# ...
# data\images\awake.2a52e043-3150-11ee-be5a-2c337afe2f50.jpg
# ...
# data\images\awake.2a52e044-3150-11ee-8072-2c337afe2f50.jpg
# ...
# data\images\awake.2a53074c-3150-11ee-a19d-2c337afe2f50.jpg
# ...
# data\images\awake.2a53074d-3150-11ee-bda7-2c337afe2f50.jpg
# ...
# data\images\awake.2a53074e-3150-11ee-897c-2c337afe2f50.jpg
# ...
# data\images\awake.2a53074f-3150-11ee-a3d9-2c337afe2f50.jpg
# ...
# data\images\awake.2a530750-3150-11ee-9a7b-2c337afe2f50.jpg
# ...
# data\images\awake.2a530751-3150-11ee-b14a-2c337afe2f50.jpg
# ...
# data\images\awake.2a530752-3150-11ee-b909-2c337afe2f50.jpg
# ...
# data\images\awake.2a530753-3150-11ee-b19b-2c337afe2f50.jpg
# ...
# data\images\awake.2a530754-3150-11ee-9242-2c337afe2f50.jpg
# ...
# data\images\awake.2a530755-3150-11ee-8942-2c337afe2f50.jpg
# ...
# data\images\awake.2a530756-3150-11ee-9379-2c337afe2f50.jpg
# ...

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# Cloning into 'labelImg'...
# error: RPC failed; curl 92 HTTP/2 stream 5 was not closed cleanly: CANCEL (err 8)
# error: 1253 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#   Using cached PyQt5-5.15.9-cp37-abi3-win_amd64.whl (6.8 MB)
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for PyQt5-sip<13,>=12.11 from https://files.pythonhosted.org/packages/41/83/f8dafe9671b868279771eca37c8d54af7514eaeaf71e571cfbea027114e5/PyQt5_sip-12.12.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# ...
#    ---------------------------------------- 3.8/3.8 MB 168.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 78.4/78.4 kB 161.9 kB/s eta 0:00:00
# ...
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Python311\Lib\site-packages\mpmath-1.3.0.dist-info due to invalid metadata entry 'name'
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\Bhavin Joshi\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
# ...

# %%
model=torch.hub.load('ultralytics/yolov5','custom',path="C:/Users/Bhavin Joshi/Desktop/Prog/Python/Drowsiness/yolov5/runs/train/exp/weights/last.pt",force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Bhavin Joshi/.cache\torch\hub\master.zip
# YOLOv5  2023-8-5 Python-3.10.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img=os.path.join("data","images","drowsy.6bb11185-3153-11ee-bc4a-2c337afe2f50.jpg")

# %%
results=model(img)
# Out:
# WARNING  NMS time limit 0.550s exceeded

# %%
results.print()
# Out:
# image 1/1: 480x640 1 drowsy
# Speed: 1025.4ms pre-process, 2303.7ms inference, 700.6ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
